# %%
#doing necessary installs
# !pip install sweetviz

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import sweetviz as sv
import statsmodels.formula.api as smf
import plotly.express as px

# %% [markdown]
# # Data - delivery_time

# %%
#Importing the dataset
df1 = pd.read_csv(r"C:\Users\Vanita\Downloads\delivery_time (3).csv")
df1.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
#getting the basic information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %% [markdown]
# # Creating the EDA report using Sweetviz

# %%
sweet_report1 = sv.analyze(df1)
sweet_report1.show_notebook(w=900, h=600, scale=0.8)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
#  <iframe width="900" height="600" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...
